# %%
import struct, inspect
import hexdump, zlib
import traceback

def decode_1(body):
    key = bytearray(b'\xf9\xa3\xff\xf8')
    ret = bytearray(body)
    ## 0F8FFA3F9h
    for i in range(len(body)):
        ret[i] = ret[i] ^ key[i%4]
    return bytes(ret)

def decode_2(body):
    compressed_len = struct.unpack('i', body[8:12])[0]
#     key = bytearray(b'\xf9\xa3\xff\xf8')
    key = struct.unpack('i', b'\xf9\xa3\xff\xf8')[0]
#     key = bytearray(struct.pack('i', 0xf8ffa3f9 - compressed_len))
    key = bytearray(struct.pack('i', key - compressed_len))
    ret = bytearray(body)
    ## 0F8FFA3F9h
    for i in range(len(body)):
        ret[i] = ret[i] ^ key[i%4]
    for i in (8, 9, 10, 11):
        ret[i] = ret[i] ^ key[i%4]
    return bytes(ret)

def decode_block_header(body):
    origin_len, compressed_len = struct.unpack('ii', body[8:16])
    key = struct.unpack('i', b'\xf9\xa3\xff\xf8')[0]
    compressed_len = compressed_len ^ key - origin_len
    key = struct.pack('i', key - origin_len)
    return key, compressed_len, origin_len

def decode_block_bak(body, key):
    ret = bytearray(body)
    key = bytearray(key)
#     end = ((len(body) - 4) >> 2) << 2  # last 4 bytes never encode
#     end_2 = (len(body) >> 4) << 4
    end = ((len(body) ) >> 2) << 2
    if end_2 > end:
        end = end_2
    for i in range(end):
        ret[i] = ret[i] ^ key[i%4]
    return ret

def decode_block_bak_2(body, key):
    ret = bytearray(body)
    key = bytearray(key)
    a2 = len(body) + 16
    v13 = a2 - 4;
    v15 = (a2 - 21) >> 2;
    v16 = v15 + 1;
    v17 = ((v15 - 3) >> 2) + 1;
    v18 = 4 * v17;
    v23 = 16 * v17 + 16;
    if v16 == v18:
        end = 16*v17
    else:
        end = 16*v17 + 4
        if v23 + 4 < v13:
            end += 4
            if v23 + 8 < v13:
                end += 4
    for i in range(end):
        ret[i] = ret[i] ^ key[i%4]
    return ret

def decode_block(body, key):
    ret = bytearray(body)
    key = bytearray(key)
    end = (len(body)-1) >> 2 << 2
    for i in range(end):
        ret[i] = ret[i] ^ key[i%4]
    return ret

level_shift_right = {19:9, 17:11, 15:12, 12:16, 10:16, 9:18, 7:20, 5:22}
level_shift_left = {19:7, 17:5, 15:4, 12:0, 10:0, 9:0, 7:0, 5:0}

def xy_2_idx(x, y, level):
    shift = level_shift_right[level]
    x = x >> shift
    y = y >> shift
    c3 = (x & 0x7) | ((y & 0x7) << 3)
    c2 = ((x>>3) & 0x7) | (((y>>3) & 0x7) << 3)
    c1 = ((x>>6) & 0x7) | (((y>>6) & 0x7) << 3)
    shift_c0 = level_shift_left[level]
    x = x >> 9
    y = y >> 9
    c0 = x | ( y << shift_c0 )
    return c0, c1, c2, c3

def idx_2_xy(idx, level):
    c0, c1, c2, c3 = idx
    t = 2**level_shift_left[level] - 1
    n = c0 & t
    n = (c1 & 0x7) | (n << 3)
    n = (c2 & 0x7) | (n << 3)
    n = (c3 & 0x7) | (n << 3)
    n = n << level_shift_right[level]
    x = n
    c0 = c0 >> level_shift_left[level]
    c1 = c1 >> 3
    c2 = c2 >> 3
    c3 = c3 >> 3
    n = c0 & t
    n = (c1 & 0x7) | (n << 3)
    n = (c2 & 0x7) | (n << 3)
    n = (c3 & 0x7) | (n << 3)
    n = n << level_shift_right[level]
    y = n
    return x, y

powers = {(1<<i):1 for i in range(17)}

def get_layer_by_id(block, id):
    for layer in block.layer:
        if layer.layerId == id:
            return layer

trick = [0]
        

class VMap():
    def __init__(self, filename='/tmp/shanghai_289.dat'):
        self.dz = zlib.decompressobj()
        content = open(filename, 'rb').read()
        self.content = content
        c = content
        self.size_all = len(c)
        s = struct.unpack('i', c[0x20:0x24])[0]
        self.size_h0 = 0x20 + 4 + s
        h1 = c[self.size_h0:self.size_h0+0x100]
        h1 = decode_1(h1)
        p = self.size_h0+0x100
        self.level_count = struct.unpack('i', h1[0x50:0x54])[0]
        self.size_trees = struct.unpack('i', h1[0x9C:0x9C+4])[0]
        levels = []
        self.levels = levels
        self.size_h1 = 0x100
        self.size_h2 = 0x40 * self.level_count
        h2 = c[p:p+self.level_count*0x40]
        h2 = decode_1(h2)
        self.levels_info = {}
        for i in range(self.level_count):
            levels.append(struct.unpack('h', h1[0x58+8*i:0x58+2+8*i])[0])
            root = struct.unpack('i', h2[0x40*i+0x10:0x40*i+0x10+4])[0]
            self.levels_info[levels[i]] = {}
            self.levels_info[levels[i]]['root'] = root
            s00, s01, s10, s11, s20, s21, s30, s31 = struct.unpack('BBBBBBBB', h2[0x40*i:0x40*i+8])
            assert s00 == s01 and s10 == s11 and s20 == s21 and s30 == s31
            self.levels_info[levels[i]]['idx_block_size'] = s00*s01, s10*s11, s20*s21, s30*s31 # idx item size not byte size
        for i in range(self.level_count-1):
            self.levels_info[levels[i]]['end'] = self.levels_info[levels[i+1]]['root']
        self.levels_info[levels[-1]]['end'] = self.size_h1+self.size_h2+self.size_trees
        h = self.size_h0 + self.size_h1 + self.size_h2
        self.idx_part = h1+h2+decode_1(c[h:h+self.size_trees-4])+c[h+self.size_trees-4:h+self.size_trees]
        
    def get_block_pos(self, loc):
        header = self.content[loc+0x2f:loc+0x2f+0x10]
        key, compressed_len, origin_len = decode_block_header(header)
        block = self.content[loc+0x2f+0x10:loc+0x2f+0x10+compressed_len]
        block = decode_block(block, key)
        dz = zlib.decompressobj()
        block = dz.decompress(block)[:origin_len]
        return block            

    def get_block_xy(self, xy, level):
        c0, c1, c2, c3 = xy_2_idx(xy[0], xy[1], level)
        n0 = self.levels_info[level]['root']
        p = n0 + c0*4
        n1 = struct.unpack('i', self.idx_part[p:p+4])[0]
        p = n1 + c1*4
        n2 = struct.unpack('i', self.idx_part[p:p+4])[0]
        p = n2 + c2*4
        n2 = struct.unpack('i', self.idx_part[p:p+4])[0]
        p = n2 + c3*4
        n3 = struct.unpack('i', self.idx_part[p:p+4])[0]
        header = self.content[n3+0x2f:n3+0x2f+0x10]
#         return header
        key, compressed_len, origin_len = decode_block_header(header)
        print(key, compressed_len, origin_len)
        block = self.content[n3+0x2f+0x10:n3+0x2f+0x10+compressed_len]
#         return block
        block = decode_block(block, key)
        assert block[:2] == b'\x78\x9C'
#         assert False
        dz = zlib.decompressobj()
        block = dz.decompress(block)[:origin_len]
        return block
        
    def __repr__(self):
        atts = {}
        for i in dir(self):
#             print(i)
            if i[0] == '_' or i in ('contentaa', ) :
                continue
            att = self.__getattribute__(i)
            if type(att) == bytes:
                continue
            if inspect.ismethod(att):
                continue
            atts[i] = att
#         print(type(atts))
#         print(atts.keys())
#         return 'gogogo'
        return '%s ==> %s'%('hello',atts.__repr__())
    
    def walk_idx_tree_bak(self, level):
        s0 = self.levels_info[level]['root']
        e0 = self.levels_info[level]['end']
        p0 = s0
        size_0 = 0
        size_1 = 0
        size_2 = 0
        size_3 = 0
        while True:
            v = struct.unpack('i', self.idx_part[p0:p0+4])[0]
            if v > 0:
                size_0 = v - s0
                assert size_0 in powers
                print('size_0', size_0)
                break
            p0 += 4
        e0 = s0 + size_0
        v0 = []
        for i in range(size_0>>2):
            v = struct.unpack('i', self.idx_part[s0+i*4:s0+i*4+4])[0]
            if v > 0: v0.append(i)
        if size_1 == 0 and len(v0) > 1:
            ii_0, ii_1 = s0 + v0[0]*4, s0 + v0[1]*4
            size_1 = struct.unpack('i', self.idx_part[ii_1:ii_1+4])[0] - struct.unpack('i', self.idx_part[ii_0:ii_0+4])[0]
            assert size_1 in powers
            print('size_1', size_1)
        for i_1 in v0:
            s1 = struct.unpack('i', self.idx_part[s0+i_1*4:s0+i_1*4+4])[0]
            p = s1
            if size_1 == 0:
                while True:
                    v = struct.unpack('i', self.idx_part[p:p+4])[0]
                    if v > 0:
                        size_1 = v - s1
                        assert size_1 in powers
                        print('size_1', size_1)
                        break
                    p += 4
            e1 = s1 + size_1
            v1 = []
            for i in range(size_1>>2):
                v = struct.unpack('i', self.idx_part[s1+i*4:s1+i*4+4])[0]
                if v > 0: v1.append(i)
            if size_2 ==0 and len(v1) > 1:
                ii_0, ii_1 = s1 + v1[0]*4, s1 + v1[1]*4
                size_2 = struct.unpack('i', self.idx_part[ii_1:ii_1+4])[0] - struct.unpack('i', self.idx_part[ii_0:ii_0+4])[0]
                assert size_2 in powers
                print('size_2', size_2)
            for i_2 in v1:
                s2 = struct.unpack('i', self.idx_part[s1+i_2*4:s1+i_2*4+4])[0]
                p = s2
                if size_2 == 0:
                    while True:
                        v = struct.unpack('i', self.idx_part[p:p+4])[0]
                        if v > 0:
                            size_2 = v - s2
                            assert size_2 in powers
                            print('size_2', size_2)
                            break
                        p += 4
                e2 = s2 + size_2
                v2 = []
                for i in range(size_2>>2):
                    v = struct.unpack('i', self.idx_part[s2+i*4:s2+i*4+4])[0]
                    if v > 0: v2.append(i)
                if size_3 == 0 and len(v2) > 1:
                    ii_0, ii_1 = s2 + v2[0]*4, s2 + v2[1]*4
                    size_3 = struct.unpack('i', self.idx_part[ii_1:ii_1+4])[0] - struct.unpack('i', self.idx_part[ii_0:ii_0+4])[0]
                    assert size_3 in powers
                    print('size_3', size_3)
                for i_3 in v2:
                    s3 = struct.unpack('i', self.idx_part[s2+i_3*4:s2+i_3*4+4])[0]
                    p = s3
                    if size_3 == 0:
                        while True:
                            v = struct.unpack('i', self.idx_part[p:p+4])[0]
                            if v > 0:
                                if v > self.levels_info[level]['end']:
                                    size_3 = self.levels_info[level]['end'] - s3
                                else:
                                    size_3 = v - s3
                                assert size_3 in powers
                                print('size_3', size_3)
                                break
                            p += 4
                    e3 = s3 + size_3
                    for i in range(size_3>>2):
                        v = struct.unpack('i', self.idx_part[s3+i*4:s3+i*4+4])[0]
                        if v > 0:
#                             print('###########> ', hex(i_1), i_1, i_2, i_3, i)
                            pass
                            if i_2 == 0x2b and i_3 == 0x16 and i == 0x3a:
                                print('###########> ', hex(i_1), i_1, i_2, i_3, i, hex(v))
            
    def walk_idx_tree(self, level, f = None):
        s0 = self.levels_info[level]['root']
        size_0, size_1, size_2, size_3 = self.levels_info[level]['idx_block_size']
        n = 0
        for i_0 in range(size_0):
            c0, = struct.unpack('i', self.idx_part[s0+i_0*4:s0+i_0*4+4])
            if c0 > 0:
                for i_1 in range(size_1):
                    c1, = struct.unpack('i', self.idx_part[c0+i_1*4:c0+i_1*4+4])
                    if c1 > 0:
                        for i_2 in range(size_2):
                            c2, = struct.unpack('i', self.idx_part[c1+i_2*4:c1+i_2*4+4])
                            if c2 >0:
                                for i_3 in range(size_3):
                                    c3, = struct.unpack('i', self.idx_part[c2+i_3*4:c2+i_3*4+4]); trick[0] = c3
                                    if c3 > 0:
                                        if n >= 500000:
                                            return
                                        else:
                                            pass
                                        try:
                                            block = self.get_block_pos(c3)
                                            bl.Clear()
                                            bl.ParseFromString(block)
                                            if f:
                                                xy = idx_2_xy((i_0, i_1, i_2, i_3), 19)
                                                f(bl, xy)
                                            layer = get_layer_by_id(bl, 8)
                                            if layer:
#                                                 print('---------------------------', c3)
                                                n += 1
    #                                         print(get_layer_by_id(bl, 8))
#                                                 print(layer)
                                        except:
                                            traceback.print_exc()
                                            print('Oops', c3, i_0, i_1, i_2, i_3)
#                                         print('###########> ', hex(i_0), i_0, i_1, i_2, i_3)
                                        if i_1 == 0x2b and i_2 == 0x16 and i_3 == 0x3a:
                                            print('###########> ', hex(i_0), i_0, i_1, i_2, i_3)
            
import map_pb2
bl = map_pb2.Block()

def every_2_bits(raw):
    ret = []
    for n in raw:
        ret.append(n>>6)
        ret.append( (n>>4)&3 )
        ret.append( (n>>2)&3 )
        ret.append( n&3 )
    return ret

def decode_ints_with_bitmap(raw, bitmap):
    ret = []
    bitmap = every_2_bits(bitmap)
    n = 0
    for i in bitmap:
        item = 0
        for j in range(i+1):
            h = raw[n]
            item = item + (h<<(8*j))
            n += 1
        ret.append(item)
        if n == len(raw):
            break
    return ret

def lastbit_sign(a):
    if a&1:
        return (a>>1)*-1
    else:
        return a>>1
    
def pg(a, base_x=0, base_y=0, scale=1):
    x0, y0, a = a[0], a[1], a[2:]
    ret = [(x0,y0)]
    while a:
        dx, dy, a = a[0], a[1], a[2:]
        ret.append((ret[-1][0]+dx, ret[-1][1]+dy))
#     if ret[-1][0] - x0 < 0.1 and ret[-1][1] - y0 < 0.1:
#         ret[-1] = x0, y0
    ret = [(base_x+x/10, base_y+y/10) for (x, y) in ret]
    return ret

import json

out_f = None

def f1(block, base_xy):
    x, y = base_xy
#     x, y = 0, 0
    layer = get_layer_by_id(bl, 8)
    if layer:
        for body in layer.body:
            for b2 in body.b2:
                val = decode_ints_with_bitmap(b2.bo.data, b2.bo.mask)
                val = [lastbit_sign(i) for i in val]
                val = pg(val, x, y, 10)
                if out_f:
#                     out_f.write('%d %d %d'% (trick[0], base_xy[0], base_xy[1]))
                    out_f.write(json.dumps({'outline':val, 'height':b2.bo.height}))
                    out_f.write('\n')
                else:
                    print(json.dumps(val))
            

def f_poi(block, base_xy):
    x, y = base_xy
    layer = get_layer_by_id(bl, 3)
    if layer:
        for body in layer.body:
            for b2 in body.b2:
                if out_f:
                    out_f.write(json.dumps({'tag':body.tag, 'poi':b2.poi.poi, 'location':(x+b2.poi.x/100, y+b2.poi.y/100)}, ensure_ascii=False))
                    out_f.write('\n')

# %%
list(range(10))/100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-4447223bfc3c> in <module>()
# ----> 1 list(range(10))/100
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
m1 = VMap()
# m1

out_f = open('/tmp/289_poi.json', 'w')

# %time m1.walk_idx_tree(19, f_poi)

out_f.close()
# m1 = VMap('/tmp/quanguogailue.dat')
# m1.walk_idx_tree(10)
# Out:
# ###########>  0x6b3 1715 43 22 58
# CPU times: user 53.2 s, sys: 286 ms, total: 53.4 s
# Wall time: 53.4 s

# %%
def decode_b(body):
    a2 = body + 16
    v13 = a2 - 4;
    v15 = (a2 - 21) >> 2;
    v16 = v15 + 1;
    v17 = ((v15 - 3) >> 2) + 1;
    v18 = 4 * v17;
    v23 = 16 * v17 + 16;
    if v16 == v18:
        end = 16*v17
    else:
        end = 16*v17 + 4
        if v23 + 4 < v13:
            end += 4
            if v23 + 8 < v13:
                end += 4
    return end

def decode_b2(body):
    end = body >> 2 << 2
    if end == body:
        end -= 4
    print( ((body -1) >> 2 << 2) - end )
    return end

for i in range(16, 32):
    print(decode_b(i), i>>2 <<2, i)
# Out:
# 12 16 16
# 16 16 17
# 16 16 18
# 16 16 19
# 16 20 20
# 20 20 21
# 20 20 22
# 20 20 23
# 20 24 24
# 24 24 25
# 24 24 26
# 24 24 27
# 24 28 28
# 28 28 29
# 28 28 30
# 28 28 31

# %%
idx_2_xy((1715, 36, 62, 18), 19)
# Out:
# (13526016, 3568640)

# %%
out_f = None
b = m1.get_block_xy((13531904, 3647232), 19)
bl.Clear()
bl.ParseFromString(b)
bl
# Out:
# b'\xd3\x10\xff\xf8' 21829 37670
# layer {
#   layerId: 7
#   body {
#     tag: 1604
#     b2 {
#       bg {
#         data: "\001p\002\001_\026\027,;\002\005.W,\007,,\007$\305\276"
#         mask: "\020\000\000\000\000\000"
#       }
#     }
#   }
#   body {
#     tag: 1601
#     b2 {
#       bg {
#         data: ":\002D\025\t9=\240\001C>\023\006"
#         mask: "@\000\000\000"
#       }
#     }
#     b2 {
#       bg {
#         data: "\001\020\002\001?\001NLD@5@1@/2"
#         mask: "\021\000\000\000"
#       }
#     }
#   }
#   body {
#     tag: 1549
#     b2 {
#       bg {
#         data: "\340\262\003\r\005\225\237AA\0011d_\212\211\010\001\n\002\246\266\2450\001\r\014\r\002\013\002"
#         mask: "\020\000\000\000\000\020\000\000"
#       }
#     }
#     b2 {
#       bg {
#         data: "T\003b\001\275\257\240\265Z\0016.80\001F\001\001%&IR\021\0101>"
#         mask: "P\000\000\000\000\000\000"
#       }
#     }
#     b2 {
#       bg {
#         data: "\300\002*\003\241k\035\027/+y\207jg\016\nJej{nn+2\n\020\004\026\004\014* 2AHD\010\016\002\022\005\024\207\3129%\'<:&!8"
#         mask: "P\000\000\000\000\000\000\000\000\000\000\000\000"
#       }
#     }
#     b2 {
#       bg {
#         data: "\000\004\350\003\017\007M\'+\033\037*o=\'\031\017#P\207HyHy\024\027H(\010\002\001\364\001"
#         mask: "P\000\000\000\000\000\000\020"
#       }
#     }
#     b2 {
#       bg {
#         data: "\226\000\004\227\001\001\215\234\204\007\010"
#         mask: "\020\000\000"
#       }
#     }
#     b2 {
#       bg {
#         data: "X\002\000\0041\001\001A/0G,IF\233.;\260\232M\214V6\0334"
#         mask: "T\000\000\000\000\000"
#       }
#     }
#   }
#   attr_3: 2000
#   attr_4: 0
# }
# layer {
#   layerId: 4
#   body {
#     tag: 60539
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#   }
#   body {
#     tag: 60885
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#   }
#   body {
#     tag: 60534
#     b2 {
#     }
#     b2 {
#     }
#   }
#   attr_3: 4000
#   attr_4: 0
# }
# layer {
#   layerId: 16
#   body {
#     tag: 61208
#   }
#   attr_3: 11100
#   attr_4: 0
# }
# layer {
#   layerId: 4
#   body {
#     tag: 60164
#     b2 {
#     }
#   }
#   attr_3: 13000
#   attr_4: 0
# }
# layer {
#   layerId: 16
#   body {
#     tag: 61215
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#   }
#   body {
#     tag: 61226
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#   }
#   body {
#     tag: 61208
#     b2 {
#     }
#     b2 {
#     }
#     b2 {
#     }
#   }
#   attr_3: 11000
#   attr_4: 0
# }
# layer {
#   layerId: 8
#   body {
#     tag: 2766
#     b2 {
#       bo {
#         height: 35
#         data: "\324\027(\024\021\265\200\t\taU\004\r\231(\001\025\014\230A\004\010`\334\r\005eE\004\r\231\034\001\025\020\230=\004\010X\340\021\005Y=\004\r\231$\001\025\014\2309\004\010\\\314\021\005YA\004\t\235,\001\025\014\230Q\010\004X|\t\020\274\021\006l"
#         mask: "P\000\000@\000\000\000@\000\000\000@\000\000\000@\000\000@"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\300\003\024\021MA\304\365@8\271\374"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\204\031\344\004ee\210\221\274\315MU\210}\260\234\254\214\235\274%%qlie=<EEil04)0"
#         mask: "P\000\000\000\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 14
#         data: "\260\013t\021\025UA\020)\255\010\001A<\004\001\311,"
#         mask: "P\000A\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 13
#         data: "L\007\000\003\205\225XQ\204\220YT"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 36
#         data: "\250\024\304\020\r\315|\005\005eY\004\t\2314\001\025\014\234Q\004\004\\\010\001\021\005aa\010\t\231@\001\031\014\234M\004\004X\000\001\025\tUU\004\t\2314\001\025\014\230E\004\010T\374\021\005UM\004\r\225,\001\031\010\2349\004\010L\360\021\tMM\004\r\231@\001\025\010\230Y\004\010l\230\r\014\304\021\010\204"
#         mask: "P\000\000@\000@\000@\000@\000@\000\000\000@\000\000\000@\000\000@"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\310$X\020METi]Ml\205`D%0L<(1|\210]l\215u]|"
#         mask: "P\000\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "D\003\\\014\225u$1\230p)4"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 20
#         data: "\270\'\224\006\271\002\235\002\244\261\\\002D\002\001\274IL"
#         mask: "U\005\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 14
#         data: "D\tP\016yy8\002M\002xx9\002L\002"
#         mask: "PPP"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "0\n\240&\221E`\325\220Da\324"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\250!\354\005\271\001\241\001\234\251\264\001\244\001\231\244"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 22
#         data: "t$\024\026\351\221\214\355\354\220\221\354"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\370#l\003\271\001\235\001\234\251\270\001\240\001\235\244"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 19
#         data: "|$\010\n\255\002\221\002\250\265\254\002\220\002\251\264"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 19
#         data: "$\025\334\n%\001\271p\2650\034\254\031\001\250lq\260P0\261\034\001"
#         mask: "T\000\020\000\020"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 36
#         data: "\234\035\334\030\021\001\241,I\014\001\240)H"
#         mask: "T\004\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\354\033d\010mqXQhpUP"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 18
#         data: "\000(\254\301\255\300\001\001\254"
#         mask: "@\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 13
#         data: "\014\023\224\005\251\235\004\001\035\001\250\230\005\001 \001"
#         mask: "PPP"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 36
#         data: "<\017\260\016\231\001\201\340\341\004\001\014\001MT"
#         mask: "T\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 14
#         data: "\320\r\354\tU\001a\001|yX\001`\001\201x"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\224#(\014}i054(4=\034!40\014\010y\230"
#         mask: "P\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 18
#         data: "h$0\017QA\025\021|\261pL!,i\210"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\314\200\nyAx\341xDy\334"
#         mask: "\020\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 18
#         data: "8&\260\016\301}=XiM<YT<T}(9\354\244\225\234"
#         mask: "P\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\200\021\\\n]]\030\021(\005\0045\030!8\001\030AXP\251\264"
#         mask: "P\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\220\034\260\007\271\251\030!YQ\020\025\225\211\021\020\2700\001mLa\211\035\024y\2014!\255\251\210\225<@xxdq\250\001\214\001\235\244"
#         mask: "P\000\000\001\000\000\000\000\000P\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "T\005\274\022IE\314\331HD\315\330"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "8\035\234\t1\0019\001LQ$\021$\005\020,\010\001\360}\200"
#         mask: "U\000\000@\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\000(,\010\265\245\234\255\030\024\001<\001"
#         mask: "P\000\020"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\210\006\000(A\001\024!, "
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\270%P\013\305\271<A40\004\002A\002\224\220\025\030\030\024\0014\001\261\245\231\001\274\001"
#         mask: "P\000P\000\020P"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 19
#         data: "\320\'\344\002\025\003\275\002 )x\001\254\002\\\002\001T14"
#         mask: "U\000P\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 30
#         data: "D\033\300\033\235\002\265\001\025\rt\261hD(EI1`\225\024\001\264a\224A))@\310\200(A1!`\225\004\001\250a\230=-%<\\<y\274"
#         mask: "U\000\000\000@\000\000\000@\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 19
#         data: "0\"\250\014\251\002\215\002\220\225\240\002\210\002\211\230"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 36
#         data: "\360#\260\"\235\001\321\231M AU-p\341\030-<\002$\001)PH$}\374"
#         mask: "T\000\000\005\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 13
#         data: "t\020l\007}}\004\002\371\001\304\304\225\220EIu\001h\001"
#         mask: "PP\000P"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 14
#         data: "4\014\204\013myt\001]\001ltu\001`\001"
#         mask: "PPP"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 36
#         data: "l\034(\030\265m\220\3754\034\021 a\224\214P-H"
#         mask: "P\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\224\035\250\001\225\221i`\t\001\321\034\035\251\201\020\r\214\001\001Pt !8,! \304\260YX"
#         mask: "P\004\000\004\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\360\035\21459\025\030im\340\00104aX"
#         mask: "@\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 18
#         data: "\204\030D\004U]\t\325H\0015\001\214|XQLH\035\002\360\001"
#         mask: "P\005\000\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "L\020\000(\241\001T\221xH-H"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 19
#         data: "\034&H\010\255\002\231\002\240\255\264\002\224\002\251\260"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "p\033\214\002\225\001E\001\004\001\371\260\0014\001!\001\010\001"
#         mask: "UEP"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\264%\020\021MA\241y\\}\214tdLat"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "T\035\334\006\251\001\211\001\230\251\254\001\210\001\235\250"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\230\'\230\020A5\030!%\031$5 \030@a0 \001\274A))4"
#         mask: "P\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\360\006\014\021UY\320\301TX\321\300"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 19
#         data: "\314#\030\013\251\002\221\002\244\261\254\002\214\002\251\264"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 19
#         data: "T% \t\261\002\221\002\250\265\260\002\224\002\251\260"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 31
#         data: "\264\031\330\035}\002\245\001@ep\251x\002\244\001\255\014\001"
#         mask: "U\000Q\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 22
#         data: "\340\030\350$\201\002I\001P\241\200\002H\001Q\240"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 14
#         data: "\264\013$\007\221\231pe\214\224mh"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "h%\214\017M=$1U=$9\030\005\230t1@)0"
#         mask: "P\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "x\'\204\017!\021\010\031eALq\210PY\210"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "8\037\240\010\265\001\231\001\230\255\270\001\240\001\235\244"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 32
#         data: "\250\004t\023\231\001\211\001\260\271L\001D\001HD\255\270"
#         mask: "U\005\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: ",\005 \017I-\334Y\001\214\200API9\231\354"
#         mask: "P\020\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "P\031\220#]\0029\001`\275\\\0024\001a\300"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "p\"\024\005\265\001\245\001\230\251\264\001\250\001\231\244"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\034\036\004\006\251\001\211\0014=YUHM\021\001\345\244\221L\0010\001Xa\244\001\204\001\231\250\251\001\205\001-0\250\001\204\001\225\254"
#         mask: "U\000\004\005\005\005\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\020\032T\027\021\255D\001\035\020\260E\001\030"
#         mask: "P@@"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "T\'\000(q\001e\002E\0018q\300\002p\001%D"
#         mask: "PPP\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 18
#         data: "\000 @EAx\0015@"
#         mask: "@\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: " \004@\016\355\002U\002(5\354\002T\002)4"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\000\027\330\'Q\035\010!1\021H\325<\030=\250L\030\035H"
#         mask: "P\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 13
#         data: "\230\022\330\003\341\365\\\001E\001\030\0018\001\211|=A\321\304"
#         mask: "PU\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "`\036\030\031\031(\001\021\030"
#         mask: "@\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 28
#         data: "<\"\024\"\251\002U\001\250Y\001\274\001\340q\340T,!@\230L\0314"
#         mask: "U\024\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\324$D\014\311\265\r\t\270\305\310\304y\20458"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\020$T\037\335qD\211\334lE\214"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 25
#         data: "\200\031$!\211Q%<}M$=}Md\255\200\001\354!4Et"
#         mask: "P\000\000\004\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\014%<\024}Q|\315|P}\314"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\014\320\t\r\r\001\031\001\224l\211\270"
#         mask: "\020\020\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "4#@\004\265\001\235\001\230\255\270\001\244\001\235\244"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\\\034\004\010qy45px54"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 39
#         data: "\260\021`\027\241\261<9EM=8\215\225<9MQ=8\205\215<9EM=8\211\221<919\254\241D\003\204\003\030\034\255\240!!=8"
#         mask: "P\000\000\000\000\000\000\000\005\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: ",\031D\005\201\255\314\3250,\211\220ddY`"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: " \032(\005uu15hmDDddml"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 38
#         data: "\300\0278\031M\0039\003x\201XPTY55`e\330\320mt==EL\260\254HI--hu\324\320mp95IL\244\240DE))p}\324\320q|%)58@D\211\220"
#         mask: "U\000\000\000\000\000\000\000\000\000\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 19
#         data: "\204!\\\r\241\002\211\002\214\225\244\002\204\002\221\230"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "$\'\270\021\365}h\225\230t\220\271@(\001\024\001\335\030"
#         mask: "P\000\000\020\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 28
#         data: "D\033\000\037\031\001\271\220\341\030\001\274m\250%4"
#         mask: "T\004\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "0&X\r\035\001\375<E`m\030\001\374\231\260"
#         mask: "T\000@\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\000(\350\001\215\001m\001\211}X\001\274\001\230\001\001P"
#         mask: "U\000P\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\220\035\260\020\te\000\001\021\004d\375\020"
#         mask: "P@\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\\\"\034\035\0354\001\031\034"
#         mask: "@\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 34
#         data: "\214!L%\301\004q\002E\225x\351l\001\274\025X\260\003\344\001}\364"
#         mask: "U\000@P\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "0\n|%}A|\365|<}\370"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "8\0274\034\r\001\265@e\014\001\264Ad"
#         mask: "T\004\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 14
#         data: "\250\004\244\016UI@MXHEL"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\024\033\024\026\245\005\010\241\240\014\005\230"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 13
#         data: "\314\017H\010\231\001\255\001\230\231\234\001\254\001\235\230"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 20
#         data: "\000(\\\005A\002%\002\\q\344\001|\001\001\030\001"
#         mask: "U\005\020"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: " \033\360\005yyPI\024\024D\001Y\001XT\211\001\260\001"
#         mask: "P\000PP"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 13
#         data: "\250\0170\006\201\205\210\002y\002\200\204\211\002x\002"
#         mask: "PPP"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 19
#         data: "\354\"\310\013\251\002\211\002\220\231\244\002\214\002\215\224"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\324& \020\231i1,A5\020\031x\251\344\250e\210"
#         mask: "P\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\274\rx\003a]\360\t\001d\\\365\010\001"
#         mask: "P\020\020"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "l\006\300\035\375i\304\371\001\374d\305\374\001"
#         mask: "P\020\020"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 14
#         data: "\324\n\314\n\201aD]\200`E\\"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 19
#         data: "\204\021\330\016\231\221hq\r\001\005\001\224\235a]\224\231\205\201x}|\001t\001LQ\314\314el88\351\001\374\001"
#         mask: "P\005\000\000\005\000\000P"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "@\036t\n\321\305hm\320\300ip"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 17
#         data: "\001\240\014\001\001\001pHq\270"
#         mask: "\021\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\000(\014\016\245\241\240\251\004\004\001D\001"
#         mask: "P\000\020"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\300 \354\006\265\001\225\001\224\261\270\001\240\001\231\244"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 38
#         data: "\004\026\340\032!!\035\034\211\205$%UQ!$\215\211 )ie%$}y$%MM%$mi$%=9\240\251d\003L\003\255\254"
#         mask: "P\000\000\000\000\000\000\000\000\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\000$\014\017\215iEP\211\001E\001p\001\361\001|hx\231\310\26449H\014=D\034\001\3748\001i\001\230\204\001\004\341\374\330\344=\\\205QM\010A- -\355\245)8U90E\021\021\305\024\001\315\001E\001I\\\230l0E<(-8\020\020,9\300\210\201\334"
#         mask: "P\005P\000\000\004P\000\000\000\000\000\000\001P\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: ",\022<%=\001\205 M \0018\005\230"
#         mask: "T\004\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\354\004L\016\261\002\021\0024I\250\002\030\002-@"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\220\035\300\002MI10\255\251\214\21544\024\031\274\304il"
#         mask: "P\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\234$\250\002i\002A\002`i\200\001 \002\000\002\231\250"
#         mask: "U\000P\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 14
#         data: "\364\0304\016\221\211mla\001M\001hmMM(\001=\001\010\002\364\001\231\25000\211\220"
#         mask: "P\005\000U\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\370\037\304\007\255\001\231\001\224\245\260\001\234\001\231\240"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 36
#         data: "\014#\324%\255q\200\315\254l\201\320"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "t\036t\t\255\001\231\001\224\251\260\001\230\001\231\250"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\370#HQI\204\001\014\010A@"
#         mask: "@\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\024\"\240\001\251\001\205\001\034\035\020\001\001\024\001\000\001\231\240"
#         mask: "U\004P\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 17
#         data: "\330\031(\"\265m\\\231Du\264l\241\014\001"
#         mask: "P\000\001\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 14
#         data: "\350\013\000\014qm<=lp98"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 14
#         data: "\260\002L\021\261\002\311\001\001\335h\001%\002\024\003\014\002\315\001\274\002"
#         mask: "U\005U\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\310\037 \004\241\001\201\00149ie(\001M\001hd\244\001\210\001\235\244\235\001\205\00110\240\001\200\001\231\254"
#         mask: "U\000PPPP\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "\230\013\200$\311i\230!\001\304d\225$\001"
#         mask: "P\020\020"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 28
#         data: "\030\035\364\034%\001\311\260\031\001Hm\264xpL\371\210\001"
#         mask: "T\020\000\020"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 21
#         data: "\320\034d\035!\001\305Du$\001\310Ip"
#         mask: "T\004\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 20
#         data: "\344&t\007\265\002\231\002\244\261\264\002\234\002\245\254"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 12
#         data: "P!x\002\245\001\211\001\025\024yq\\m|t09\034\035\244\001\210\001\231\250"
#         mask: "U\000\000\000P\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\\\0368\001]]\324\335\204\001a\200\235\270"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#   }
#   body {
#     tag: 71163
#     b2 {
#       bo {
#         height: 46
#         data: "\264\024\250\261\251T\001\001\245\250"
#         mask: "@@\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 62
#         data: "\244\037\274\016i\001Q\001HUl\001P\001MT"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 106
#         data: "\330%t\031]18i\\0\0358\0350"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 58
#         data: "\264\022D\035\345\002!\002\220\311\344\002 \002\221\310"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 54
#         data: "4\0378\0171-<E\251\235AD]Y\005-\010!\004)89h\001P\001q|"
#         mask: "P\000\000\000\000P\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 74
#         data: "\024\"x\023mY\024\025\035\031!0E9,9\261\215=LA5<IUeLa \0340A0(\030\035\230|\025\034dP\030\035H8\025 0$!$T@=LQd"
#         mask: "P\000\000\000\000\000\000\000\000\000\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 98
#         data: "\210&8\036i9\0314\355\205\034-M-0Qx@ 9y=(E8 \0345\010\001\220\0354P,m\314"
#         mask: "P\000\000\000\000\000\004\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 106
#         data: "\234\010\310#iEL\235h@M\240"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 81
#         data: "\264\0160\021qqMM4\355}\035\031xi\031\020I@%\001h\001XQd\00148 !`h\231\224"
#         mask: "P\000\000\000\024\020\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 99
#         data: "\034\t\030$\201QL\241iA\t\001\241\200\t\001\245\001\001\001h\335\354\001,\001i\324T\001\320]\310X4u\350"
#         mask: "P\000APP@\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 119
#         data: "\210\'`&\265\002Q\001p\355\234L4u\\\001\2545p\274\\q\354"
#         mask: "U\000\004\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 83
#         data: "\004\020\000$\211E\035<I%\024)9\035\020\035\261Y\r M)\0250I%$=}A4q\024\0144m\210\002@\001%P \020E\214"
#         mask: "P\000\000\000\000\000\000\000\005\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 83
#         data: "X\025d\"Q)\r\030\321\001\315\020!\225M\030)=!H\315\\0\021$H\002$\001\020%p8\211\320"
#         mask: "P\004\000\000\000\005\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 45
#         data: "\310\001\020!q\001\035\001YY\001\311\001D\002\\\002\211p<D1,"
#         mask: "U\001P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 90
#         data: "\000(T\032\255Y\030-]5\0310\005\001\211\0349]1!8\375\205$Ea1!Da1<mL(\030-\310l\0310|@\0301\354|\035<x<\0349\324p1`8\034\001@"
#         mask: "P\000\004\000\000\000\000\000\000\000\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 93
#         data: "\374\0370\026m9$Ml8%L"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 98
#         data: "\210$`\035\t\002\035\001\024%Q-0a\\0$A]5 5X0 5\260d\0350p<\0301\010\001\214\0354,\030)D\245]!8\244X1PM)\0310"
#         mask: "U\000\000\000\000\000\000\004\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\\!\330\025A!0a\245Y\320\221\0010 \024\031hTp\2211)<MUA %pp\005D\rlq\001T\002"
#         mask: "P\000\020\000\000\000\000\000P"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 109
#         data: "\360\'\014!\321e\020%m9p\361H$\0241p8\001`\001\021$"
#         mask: "P\000\000\000\020\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 107
#         data: "\210\006\214!\355\225p\351H0\244dq\350"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 114
#         data: "\224%H\035yA\245Y 9\244\\x<!8"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 86
#         data: "\000(8\025=\035(QY)\021 \025,\035\001\215\030-\020%Y-)TQ)4iH \0345\240P\0314\270\\\0305d0\001\304"
#         mask: "P\000\000@\000\000\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 91
#         data: "\370\rt\020Y\031%\005\034u\030y|\0345\354"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 110
#         data: "(\004\270\036}E\\\251|D]\250"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 115
#         data: "\320\"\304\033]1\221Q$E\220P\\4%@"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 34
#         data: "D\037T\031\255]\021\002%\0014a9\0350Y8 \024)(\024\0345\340\001\014\001l@\035,P,%@$\024%D1\031-X"
#         mask: "PP\000\000\000P\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 81
#         data: "< @\022!\0318I$\030=H"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 86
#         data: "\364\'\354\025\365y\020)\211A\021$\361u\024%%\0254qP(\0354X,\014\031\020!\034\001\214\021 \021\034X,\034=<\034\001\234"
#         mask: "P\000\000\000\000\000\000@\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 81
#         data: "<!\354\022\301y<M\260\214-8"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 83
#         data: "$\"\314\023\315y(1 1\034\030\025\024lXPe0(q\220"
#         mask: "P\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 106
#         data: "4\'8\032]18m\\4\031,!<"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 51
#         data: "\010\027\300\037\r\003\321\001\210\361\020\003\320\001\215\360"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 98
#         data: "D\"\364\033I)\031$\t\001\221\210\375T,\0345\304l\0354< !4\221Q%D\220P1`"
#         mask: "P\004\000\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 106
#         data: "\204$\270\030]54i`0%D\025("
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 120
#         data: "`\007\004\"I\035 A,\001\005\\"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 102
#         data: "\250\'X\025Y- =$MX(E\214"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 103
#         data: "\304\004\020\037\235Y\\\251\265\001\361\230\025\001\361\001\025\001|\351@\002@\001y\344\224\001\334q\320h8\205\370"
#         mask: "P\004\025\005\004\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 70
#         data: "\344\016d\02115\230\22504\231\224"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 111
#         data: "\264\001\\\034\031\001\235\204\371X0\304p\211\364"
#         mask: "T\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 70
#         data: "$\r\344\021\205\211\000\001\001\001X\030LL!\001$\001"
#         mask: "PP\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 70
#         data: "\250\014\210\0209\311\320=\021Hh\030\035t\3250"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 16
#         data: "\\\0268\002m!\355\001\001 \001\031\001$\001l\001x\001\355\254m\024"
#         mask: "P\025\005\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 102
#         data: "8&\234\024Y-\0345(UX,E\210"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 82
#         data: "\\\017\000(E\001Q1\0350\021\001Q5\0345\365\231!8]9\0349\351\215!4Y5 5\205QH}\034\0204]\300\003D\002-P\034\020=l"
#         mask: "P\000\000\000\000\000\000\000\000\005\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 101
#         data: "\230 \204\026\235U$Mm9%Lm9(I9Q8i,\0300a\244\001\3401`@ 5h\035\021\025(=\035%H"
#         mask: "P\000\000\000\000\004\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 110
#         data: "\030\003\244\034\201IT\225|DQ\230"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 108
#         data: "\324\016P\031\001\003E\00385\000\003@\00398"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 82
#         data: "\004\026(\'U\031\0205I\031\014%\2719\r$E\031\0214M\025\0209-\r\014!a!(\201 \010\034Y\274\002\330\035\\$\010)\204Q\031\r A\025\0214"
#         mask: "P\000\000\000\000\000\000\000\004\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 61
#         data: "<\0028!EU=E\210q\200\234\211l"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 90
#         data: "\250\'\014\0335\001\245\030-\275e\025,m9\030-\005\001\215\025 \305iP\235`0\025$\\4\024)\374\204\0310\\0\0341\004\001\210!<\\0 =\254X\001\020Y\250"
#         mask: "T\000\000\004\000\000\000\000\000\004\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\364\036@\032\311}l\315\254\\,Y0\030\255,\001"
#         mask: "P\000\000\020"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 83
#         data: "h\021L \331-\t\030e\001y\010%\2315\0141A\031\0245\031\t4\225` \t$h\002\324\010!t(e\334"
#         mask: "P\004\000\000\000\000\004\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 85
#         data: "$\037\300\025M-<m$\024\025$(\030)H"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 120
#         data: "8\037`\021-=0=\005x"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 62
#         data: "\344\036,\017\251\235\034!@E\250\234=D! "
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 107
#         data: "\264\007\320!iED\215h@E\220"
#         mask: "P\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 89
#         data: "\360 \260\026Y-$I<\034\024)\034\0209p"
#         mask: "P\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 6
#         data: "\304\037\320\030%\025$AQ-\034-mA\344\261\001\220PX,-\001 \002"
#         mask: "P\000\000\020\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 56
#         data: "\214\025\030\035\0314\001\031\030"
#         mask: "@\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#   }
#   body {
#     tag: 71164
#     b2 {
#       bo {
#         height: 6
#         data: ",\005\330\026\020)%\001\211\234\004i\004\231\034\001\004\001H\345\001\310\001\005\005$M\375\205\231\024\001\300d]\001H\001"
#         mask: "PE\024P\000\020P"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 41
#         data: "\334\013H!9\001\245\021\t4i!\001\231,]\025\001\221$M\r\001\215\214%\001\014\001\214!D\034\001\224A\214 \001\230-\\<\001\240\201\020\001"
#         mask: "T\000@@A@@@A\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 45
#         data: "\324\004\000(\315\002\001\t\002\205\001\001\301\001$1\260\004t\003"
#         mask: "TQ\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 15
#         data: "\001\250\027\001\311\002\274\002\365\002`\001P\001\035\004l\004"
#         mask: "\021UP"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 41
#         data: "8\rd\0365\001\241\021\t4i!\001\225,]\025\001\215$Q\r\001\215\214%\001\014\001\214!D\034\001\224E\220$\001\224-\\8\001\240\201\010\001"
#         mask: "T\000@@A@@@A\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 42
#         data: "@\016\230\033)\001\2254i\021\001\215(U\025\001\221(U\r\001\211\210!\0014\001\240-X\004\001\210=x(\001\2301\\\374\200y\374"
#         mask: "T\004\004\004\024\004\004\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 44
#         data: "\020\t\324\027\335}\024%\355\2010]\355}\03455\031\301e\230\025\001\374\204%L\004\004\360|\035<\344t!@\310h\215\024\001"
#         mask: "P\000\000\000\001\000\000\000\000\020"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 44
#         data: "\314\007\\\032\345i\024-\365q0e\r\001Y\0309\365e(M\345m\204!\001$\001\210\021(\025(\314`%P\374x!8\354p!@\320`m\354"
#         mask: "P\000\004\000\000\024\000\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 40
#         data: "\320\023H\025u\003Q\003|\205\\TX]55dm\344\330uxA=IL\274\264HM1-py\340\324qt=9MT\254\244DI))t\201\340\324y\200))5<HD\221\224"
#         mask: "U\000\000\000\000\000\000\000\000\000\000\000\000\000\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 29
#         data: "\264\027x\001m\001y\001\360\002\001\205\001x\001"
#         mask: "UE\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 44
#         data: "\210\017\\\031i\003\325\003\250\231h\003\320\003\251\234"
#         mask: "U\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 44
#         data: "\344\nX\024}\001\211\001\005\005EX\005\001I\230\035\001X\001\001\224\001\354\001\275\254"
#         mask: "U\000AE\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#     b2 {
#       bo {
#         height: 53
#         data: "p\034\234\r)--,\205\211,-Ya10\205\2110-Y]1,\205\2110-]])(\205\211,)99\230\225x\003\230\003\231\224"
#         mask: "P\000\000\000\000\000\000\000\000\005\000"
#         attr {
#           scale: 10
#         }
#       }
#     }
#   }
#   attr_3: 16000
#   attr_4: 0
# }
# layer {
#   layerId: 15
#   body {
#     tag: 61229
#     b2 {
#       bg {
#         data: "\350\336l\022=\t\3211\r5\005\315\016i\0148\016\001\300\004\370\003\304\013\244\004\360\005``\0079\003\344\006\305\005\240\016\001\005\020`\r)\n\250\004"
#         mask: "TUETUEP"
#       }
#     }
#     b2 {
#       bg {
#         data: "0&\010\3501&Q\020\0015\n\340)\350\021\261\003\234\010"
#         mask: "U\025P"
#       }
#     }
#     b2 {
#       bg {
#         data: "|\300\0020\304\231!M#\031\002\275\001\035\002\341\031\002\020\021\002\374\375\001\324\001y\t\030\013\315\n|\014\031\007!\006(\004\321\004\314\001\235\002\354\241\002\004\245\002\331\251\002\301\001\255\002\244\003\371\002\370\001\364\001\000\002\374\000\002\004\004\002\355\004\002\351\001<\002\235\002\354\006\031\010\244\006\261\007\324\003q\004h\001\t\002\254\375\001\r\371\001\311\361\001\201\001\355\001\265\032%\033X\003M\003\264\032(\033\300\001h\001\264\001\260\260\001\021\254\001\315\244\001\211\001<\005!\006`\001\001\002\250\365\001\025\345\001\315\325\001\205\001\305\001,\003q\003\320\001T\001\310\001\240\274\001\035\264\001\321\250\001\211\001\030\007 \006e\001\000\002\245\364\001\020\350\001\314\340\001\204\001\324\001A\003`\003\311\001a\001\301\001\245\271\001\024\255\001\320\231\001x\001U\005<\006]\001\374\001\255\370\001\020\344\001\310\320\001\210\001\304\001)\003x\003\325\001U\001\311\001\235\301\001\034\265\001\320\215\001l\001\005\004\244\004\241\001d\002\325x\002\020t\002\364l\002\330\001h\002\210!<#e\003<\003"
#         mask: "\225TDUUU\021\025UDEUUQ\021UUTDUQ\021UTDUQ\021UTDUQ\021UTDUQ\021UP"
#       }
#     }
#     b2 {
#       bg {
#         data: "\354\352\002\024=Y\007\315\005\034\021\261\025!\215\001\241#\371\037\031\025\014\016\001\354\033\024\031\024\004\244\003\214d\006\205\024\370\031"
#         mask: "\225QPEQP"
#       }
#     }
#     b2 {
#       bg {
#         data: "\000 \003\200\025\255\031\201\025\200\016\001,\013P\t\0010\014"
#         mask: "\225E\020"
#       }
#     }
#     b2 {
#       bg {
#         data: "\000 \003 \2611\025\201\022\214\001\305\001\321\001}\001t\025\001\032\001\\\007e\020\334\023d\020P\016\0018\006"
#         mask: "\225UQU\020"
#       }
#     }
#     b2 {
#       bg {
#         data: "\260\317\230\240\002\345\001\365\003\351\001\275\003\361\001\205\003\365\001M\003\371\001\025\003\2215\021A@\007\365\005\3247\324C\030\003 \003\030\003\364\001\\\003H\001\340\003x\214\007U\004|\017!\026h\001\245\002\210\225\002Y\221\002=\001\205\002!\002}\002\200\006\301\006<\002\270\001,\002\310 \002\035\020\002\t\001\004\002\365\001\204\017\271\022\210\003]\007\234=\002T\271\003\215\001\375\003!\010U\t\001\006]\003-\003\341\002\r\002\331\001\035C\331<$\003}\003\021\004U\002\020\022e\037,\010\265\013\000\002e\003$\001%\003@\345\002\245\251\002\205\001i\002\211\027\221\033\224\003\r\003\214\027\230\033\230\001p\001\234\001\240\234\001=\230\001\025\001\230\001\355\001\310\007<\0051\001T\002mP\002XT\002\034\001P\002\340\001L\002\261\006\220\006\271\001e\001\251\001\245\231\001 \211\001\350]\001\204\001\355\007T\013\025\020\364\033L@L:\220\004 \004\254\2348\0034\007h\010\244\tx\002\240\006\205\340\0059\314Y\004\024\t\t\020d\023\375\016\254\023\345\017\274\026q\t\250\005U\001P\361\001%\r\002\3701\001\334\001\031\250\002\010\001p\003a\td"
#         mask: "eUUUUUEU\021UUDUU\021UUUUUU\021UUTEUQ\025UTDUUPUQ\005UUDE\025@"
#       }
#     }
#     b2 {
#       bg {
# ...
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 37598
#         y: 8400
#         attr_3: 16
#         attr_4: -5396141376603508629
#         attr_5: 6329
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\313\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 37384
#         y: 2718
#         attr_3: 16
#         attr_4: -6551214500083266883
#         attr_5: 6327
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\504\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 51156
#         y: 21314
#         attr_3: 16
#         attr_4: 2510864795893370069
#         attr_5: 6247
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\5007\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 45338
#         y: 2941
#         attr_3: 16
#         attr_4: 3247487066448997696
#         attr_5: 6068
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\930\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 42586
#         y: 10294
#         attr_3: 16
#         attr_4: 9010357226054160452
#         attr_5: 5996
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257449\345\274\204\\432\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 40984
#         y: 13599
#         attr_3: 16
#         attr_4: 6965682017667174803
#         attr_5: 5923
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\237\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 40891
#         y: 2129
#         attr_3: 16
#         attr_4: -5613525473417026191
#         attr_5: 5829
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\805\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 40784
#         y: 12690
#         attr_3: 16
#         attr_4: -1451674532890480011
#         attr_5: 5734
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257449\345\274\204\\234\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 42993
#         y: 16596
#         attr_3: 16
#         attr_4: -2492689865910812974
#         attr_5: 5641
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\154\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 39263
#         y: 9602
#         attr_3: 16
#         attr_4: 6792689663466070252
#         attr_5: 5561
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\423\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 50090
#         y: 5388
#         attr_3: 16
#         attr_4: -4940539288268200964
#         attr_5: 5433
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\1045\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 44359
#         y: 3996
#         attr_3: 16
#         attr_4: 7810180572057862258
#         attr_5: 5208
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\820\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 40237
#         y: 8526
#         attr_3: 16
#         attr_4: -8020882676660577817
#         attr_5: 4919
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\519\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 43692
#         y: 1
#         attr_3: 16
#         attr_4: 1334664718686995323
#         attr_5: 4793
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\1008\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 41479
#         y: 15018
#         attr_3: 16
#         attr_4: 5417338175569045841
#         attr_5: 4641
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\241\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 47404
#         y: 651
#         attr_3: 16
#         attr_4: -2732470412410478004
#         attr_5: 4548
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\1102\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 39932
#         y: 6333
#         attr_3: 16
#         attr_4: 1904462023871025149
#         attr_5: 4413
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\516\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 38498
#         y: 7397
#         attr_3: 16
#         attr_4: 9143045396909647553
#         attr_5: 4374
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\413\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 48471
#         y: 7459
#         attr_3: 16
#         attr_4: 4081570802567893595
#         attr_5: 4264
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\937\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 9184
#         y: 27494
#         attr_3: 16
#         attr_4: -3114739766663343334
#         attr_5: 3995
#         attr_6: 4
#         poi: "\345\206\205\346\261\237\350\267\257\344\270\200\345\205\255\345\205\253\345\274\204\\18\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 37588
#         y: 5691
#         attr_3: 16
#         attr_4: 6163010974085424826
#         attr_5: 3917
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\404\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 44356
#         y: 11900
#         attr_3: 16
#         attr_4: 2359258931140422037
#         attr_5: 3884
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257449\345\274\204\\545\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 10029
#         y: 42933
#         attr_3: 16
#         attr_4: 1206827896283241101
#         attr_5: 3778
#         attr_6: 4
#         poi: "\345\206\205\346\261\237\350\267\257\344\270\200\345\205\255\345\205\253\345\274\204\\5\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 47357
#         y: 4940
#         attr_3: 16
#         attr_4: 6215703872279927050
#         attr_5: 3732
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\934\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 41985
#         y: 11793
#         attr_3: 16
#         attr_4: -4352174803219516902
#         attr_5: 3341
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\336\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 49092
#         y: 1895
#         attr_3: 16
#         attr_4: -282413397821748669
#         attr_5: 3318
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\1103\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 46289
#         y: 6189
#         attr_3: 16
#         attr_4: -6963018399033485376
#         attr_5: 3184
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\831\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 42378
#         y: 6135
#         attr_3: 16
#         attr_4: 2233788572834226037
#         attr_5: 2919
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\616\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 47786
#         y: 11605
#         attr_3: 16
#         attr_4: 3595701801272302896
#         attr_5: 2890
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\653\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 38789
#         y: 4794
#         attr_3: 16
#         attr_4: -7313625584017250517
#         attr_5: 2817
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\506\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 50628
#         y: 16770
#         attr_3: 16
#         attr_4: 5848100932201451620
#         attr_5: 2668
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257449\345\274\204\\5012\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 39585
#         y: 11605
#         attr_3: 16
#         attr_4: -1803972747562873485
#         attr_5: 2643
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\230\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 46485
#         y: 9601
#         attr_3: 16
#         attr_4: -8791841823031176664
#         attr_5: 2571
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\741\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 43698
#         y: 9292
#         attr_3: 16
#         attr_4: -4988465268180573878
#         attr_5: 2474
#         attr_6: 4
#         poi: "\345\256\232\346\265\267\350\267\257\345\233\233\345\233\233\344\271\235\345\274\204\\534\345\217\267\346\245\274"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#   }
#   body {
#     tag: 540
#     b2 {
#       poi {
#         x: 25794
#         y: 37516
#         attr_3: 112
#         attr_4: 554529664905441956
#         attr_5: 11015
#         attr_6: 0
#         poi: "\345\215\227\351\227\250"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 3507
#         y: 32522
#         attr_3: 112
#         attr_4: 3170706920821084545
#         attr_5: 10780
#         attr_6: 1
#         poi: "\350\245\2771\351\227\250"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 38603
#         y: 18711
#         attr_3: 48
#         attr_4: 1330733599753667050
#         attr_5: 10236
#         attr_6: 3
#         poi: "\345\215\2272\351\227\250"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 40836
#         y: 19818
#         attr_3: 48
#         attr_4: -6712814071269241415
#         attr_5: 8054
#         attr_6: 1
#         poi: "\344\270\234\345\215\2271\351\227\250"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 37504
#         y: 17004
#         attr_3: 48
#         attr_4: -8698953494022309733
#         attr_5: 7549
#         attr_6: 0
#         poi: "\345\215\2271\351\227\250"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 42385
#         y: 31351
#         attr_3: 48
#         attr_4: -448611060644052993
#         attr_5: 7195
#         attr_6: 1
#         poi: "\350\245\277\351\227\250"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 15381
#         y: 26304
#         attr_3: 48
#         attr_4: -5844796620225486839
#         attr_5: 7061
#         attr_6: 1
#         poi: "\344\270\234\345\215\227\351\227\250"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 41613
#         y: 20706
#         attr_3: 16
#         attr_4: 7571787500486394311
#         attr_5: 6288
#         attr_6: 0
#         poi: "\344\270\234\345\215\2272\351\227\250"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#     b2 {
#       poi {
#         x: 37795
#         y: 34178
#         attr_3: 16
#         attr_4: -1510843749703177181
#         attr_5: 4090
#         attr_6: 0
#         poi: "\345\214\227\351\227\250"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#   }
#   body {
#     tag: 258
#     b2 {
#       poi {
#         x: 31070
#         y: 139
#         attr_3: 112
#         attr_4: -4684483931357902880
#         attr_5: 10657
#         attr_6: 1
#         poi: "\347\246\204\345\237\216\347\204\212\346\216\245\345\212\240\345\267\245"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#   }
#   attr_3: 18000
#   attr_4: 0
# }

# %%
out_f = None
b = m1.get_block_pos(444831 )
bl.Clear()
bl.ParseFromString(b)
bl
# f1(b,(100000,80000))
# Out:
# layer {
#   layerId: 7
#   body {
#     tag: 2513
#     b2 {
#       bg {
#         data: "\000\004\350\001\365\026\t\001\014\033\001\r\353=\001\035\244\001.\\\002#\0016"
#         mask: "PD\000D\000"
#       }
#     }
#     b2 {
#       bg {
#         data: "\000\004\350\001\365\026\t\001\014\033\001\r\353=\001\035\244\001.\\\002#\0016"
#         mask: "PD\000D\000"
#       }
#     }
#   }
#   attr_3: 2000
#   attr_4: 0
# }
# layer {
#   layerId: 15
#   body {
#     tag: 61229
#     b2 {
#       bg {
#         data: "\274\374\000 \003a\t\001\370\241\001\001\370\003\005\033\330\035\006\320\003)\035\000\004\r\004<\tE\001\020\335h\002\031`\t\t\334q\002Y\005\274\301\003\264\034U\004,\035\371D\001\001"
#         mask: "d%\025UQTU "
#       }
#     }
#     b2 {
#       bg {
#         data: "\000 \003x\\\341\247i0\234\002\005\tD\245\254/\001\300\t"
#         mask: "\225U\020"
#       }
#     }
#     b2 {
#       bg {
#         data: "\3509\002p\363\341\010\371\002\360?m\276\230\305\0025Y\002\001\001\361\001\315\001\205\001\231\002\035\001\271C\211\024\321\016u\004\2453e\017\324 \001\220\021<\005\340\002\204x\002I\014\002\031\001\250\001\345\001(\001}\002\360\t\001\371\330\002\231\274\0020X\002\374\360\001\314\001\204\001\230\002\034\001\254>\004\023\274\027\004\007\231\002\000\t\341\002}y\002P\021\002\030\001\245\001\344\0015\001\224\002\375?\210\276"
#         mask: "\225Q\025UUTTEUA\021\025UUDUU\000"
#       }
#     }
#     b2 {
#       bg {
#         data: "\230d\001p\256Y\335\261P\031\027\261\007)p\315!\001\315\t\234r\214\"\360\002\210\220\002E0\002\025\001\314\001\341\001h\001\265\002`\034\241G\030\n\001\315\0354K\261\234\002\024X\002\344\000\002\264\001\234\001\204\002@\001 \335\234P5\003\320\010"
#         mask: "\225U\025DUUE\021\025UP"
#       }
#     }
#   }
#   attr_3: 9000
#   attr_4: 0
# }
# layer {
#   layerId: 3
#   body {
#     tag: 262
#     b2 {
#       poi {
#         x: 877
#         y: 49022
#         attr_3: 240
#         attr_4: -448596973151322113
#         attr_5: 15094
#         attr_6: 0
#         poi: "\344\270\212\346\265\267\344\275\221\345\210\251\347\247\257\346\260\264\\\347\256\241\344\270\232\346\234\211\351\231\220\345\205\254\345\217\270"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#   }
#   body {
#     tag: 257
#     b2 {
#       poi {
#         x: 35954
#         y: 47810
#         attr_3: 240
#         attr_4: 5186136022192509319
#         attr_5: 14266
#         attr_6: 0
#         poi: "\351\207\221\345\261\261\345\214\272\345\273\212\\\344\270\213\351\225\207\345\267\245\344\270\232\345\214\272"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#   }
#   body {
#     tag: 60008
#     b2 {
#       poi {
#         x: 16600
#         y: 31145
#         attr_3: 240
#         attr_4: 3572034846830194858
#         attr_5: 13869
#         attr_6: 0
#         poi: "\350\200\201\350\256\241\347\272\242\346\234\250\345\256\266\345\205\267\345\216\202"
#         attr_13 {
#           attr_1: 3
#           attr_2: 0
#           attr_3: 55
#         }
#       }
#     }
#   }
#   body {
#     tag: 35
#     b2 {
#       poi {
#         x: 39702
#         y: 16796
#         attr_3: 240
#         attr_4: -8001452656610915186
#         attr_5: 10
#         attr_6: 4
#         poi: "\344\270\234\345\234\251"
#         attr_13 {
#           attr_1: 3
#           attr_2: 240
#           attr_3: 20
#         }
#       }
#     }
#   }
#   attr_3: 18000
#   attr_4: 0
# }

# %%
if abdsfo:
    pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-5f11645ad69b> in <module>()
# ----> 1 if abdsfo:
#       2     pass
#
# NameError: name 'abdsfo' is not defined

# %%
n = 0
p = 512
while p < 287232:
    v = struct.unpack('i', m1.idx_part[p:p+4])[0]
    if v > 287232:
        n += 1
    p += 4
n
# Out:
# 48418

# %%
# hexdump.hexdump(m1.idx_part)

# %%
hex(317444 - 0x4000 - 0x1000 - 0x400 - 0x4), hex(58100 - 0x10*5)
# Out:
# ('0x48400', '0xe2a4')

# %%
hex(309504), hex(0x4d804 +0x100 + 0x100 ), 0x4d804
# Out:
# ('0x4da04', '0x4da04', 317444)

# %%
xy_2_idx((13490348 + 13491991)//2, (3585779 + 3584323)//2, 19)
idx_2_xy((1715, 43, 29, 21), 19)
xy = (13490348 + 13491991)//2, (3585779 + 3584323)//2
hexdump.hexdump(m1.get_block_xy(xy, 19))
print('-------------------------')
hexdump.hexdump(decode_2(m1.get_block_xy(xy, 12)))
# hexdump.hexdump(guess_decode(m1.get_glock_xy(xy, 19)))

decode_block_header(m1.get_block_xy(xy, 12))
# Out:
# 00000000: F8 9E FF F8 58 91 FF F8  01 05 00 00 50 9D FF F8  ....X.......P...
# -------------------------
# 00000000: 00 00 00 00 A0 0F 00 00  2C D5 01 00 56 96 00 00  ........,...V...
# (b'\xcd\xce\xfd\xf8', 38486, 120108)

# %%
m1.get_block_xy(xy, 19)
# Out:
# b'\xf8\x9e\xff\xf8X\x91\xff\xf8\x01\x05\x00\x00P\x9d\xff\xf8'

# %%
# hexdump.hexdump(m1.get_block_xy(xy, 19))
# m1.get_block_xy(xy, 19)

# %%
# hexdump.hexdump(m1.get_block_xy(xy, 19))

# %%
cc = m1.get_block_xy(xy, 12)
import zlib


dd = dz.decompress(cc)
# len(dd)
# Out:
# b'\xcd\xce\xfd\xf8' 38486 120108
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-107-2389d5d58f14> in <module>()
#       3
#       4
# ----> 5 dd = dz.decompress(cc)
#       6 # len(dd)
#
# error: Error -3 while decompressing data: incorrect data check

# %%
open('/tmp/z.bin', 'wb').write(cc)
# Out:
# 38486

# %%
dz = zlib.decompressobj()
u = dz.decompress(cc)
len(u)
# Out:
# 120118

# %%
# hexdump.hexdump(cc)
